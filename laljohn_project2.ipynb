# %% [markdown]
# <a href="https://colab.research.google.com/github/9121962792/codsoft/blob/main/laljohn_project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_excel(r"/content/Advertising Dataset.xlsx")

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.isnull()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
data.dropna()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
clean_data = data.copy()

# %%
clean_data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
clean_data['cols'] = clean_data['Sales']

# %%
clean_data['cols'].head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: cols, dtype: float64

# %%
y = clean_data[['cols']].copy()

# %%
y.head()
# Out:
#    cols
# 0  22.1
# 1  10.4
# 2   9.3
# 3  18.5
# 4  12.9

# %%
y.columns
# Out:
# Index(['cols'], dtype='object')

# %%
training_set =clean_data[['TV','Radio','Newspaper']]

# %%
x = training_set.copy()

# %%
x.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper'], dtype='object')

# %%
train, test = train_test_split(data, test_size=0.33)

# %%
X_train = np.array(train.index).reshape(-1, 1)
y_train = train['Sales']

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-0.00837312])

# %%
 model.intercept_
# Out:
# 15.101794460802079

# %%
X_test = np.array(test.index).reshape(-1, 1)
y_test = test['Sales']

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (134, 1)
# X_test shape: (66, 1)
# y_train shape: (134,)
# y_test shape: (66,)

# %%
data.shape
# Out:
# (200, 5)

# %%
y_pred = model.predict(X_test)

# %%
randints = np.random.randint(200, size=25)

# %%
data_sample = data[data.index.isin(randints)]

# %%
data_sample.head()
# Out:
#     Unnamed: 0     TV  Radio  Newspaper  Sales
# 18          19   69.2   20.5       18.3   11.3
# 22          23   13.2   15.9       49.6    5.6
# 26          27  142.9   29.3       12.6   15.0
# 29          30   70.6   16.0       40.8   10.5
# 30          31  292.9   28.3       43.2   21.4

# %%
data['Prediction'] = model.predict(np.array(data.index).reshape(-1, 1))

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales  Prediction
# 0           1  230.1   37.8       69.2   22.1   15.101794
# 1           2   44.5   39.3       45.1   10.4   15.093421
# 2           3   17.2   45.9       69.3    9.3   15.085048
# 3           4  151.5   41.3       58.5   18.5   15.076675
# 4           5  180.8   10.8       58.4   12.9   15.068302

# %%
from sklearn import metrics

# %%
data['Sales'].describe()
# Out:
# count    200.000000
# mean      14.022500
# std        5.217457
# min        1.600000
# 25%       10.375000
# 50%       12.900000
# 75%       17.400000
# max       27.000000
# Name: Sales, dtype: float64

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.752130251150969
# Mean Squared Error: 34.08806838430861
# Root Mean Squared Error: 5.838498812563775

# %%
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# R2:  -0.0273474727640175

# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(y_test, y_pred)
# Out:
# -0.01057666453134698
